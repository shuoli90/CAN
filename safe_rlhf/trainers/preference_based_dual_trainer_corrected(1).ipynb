# %%
import numpy as np
import torch
from scipy.special import softmax
import matplotlib.pyplot as plt

# %%
class DualOptimizer():
    def __init__(self,
                 ref_log_probs_sum,
                 helpfulness_log_probs_sum,
                 safety_log_probs_sum,
                 kl_coeff,
                 margins, # E_{pi}[safety] - E_{pi_ref}[safety]>= margins
                 **kwargs):
        self.helpfulness_scores = helpfulness_log_probs_sum - ref_log_probs_sum
        self.safety_scores = safety_log_probs_sum - ref_log_probs_sum
        self.margins = margins
        self.kl_coeff = kl_coeff
        self.kl_divs = np.mean(ref_log_probs_sum-safety_log_probs_sum)
        self.kwargs = kwargs
    
    def log_mean_Z_values(self, logits):
        return np.log(np.mean(np.exp(logits-logits.max(axis=1).reshape(-1, 1)), axis=1))+logits.max(axis=1)
    
    def solve(self, optimizer='GD', set_optimum=False, verbose=False, **kwargs):
        lam_init = 1 if 'lam_init' not in kwargs.keys() else kwargs['lam_init']
        lr = 1 if 'lr' not in kwargs.keys() else 2*kwargs['lr']
        max_iters = 200 if 'num_iters' not in kwargs.keys() else kwargs['num_iters']
        if optimizer == 'GD':
            is_converge = False
            num_loops = 0
            while not is_converge:
                lam = lam_init
                lr = lr/2**num_loops # learning rate decay
                lam_trajectory = [lam_init]
                for idx_iter in range(max_iters):
                    logits = (self.helpfulness_scores + self.safety_scores * lam)
                    sm_probs = softmax(logits, axis=1)
                    gradient = np.sum(sm_probs * self.safety_scores, axis=1).mean() + self.kl_divs-self.margins/self.kl_coeff
                    lam = np.maximum(lam - lr*gradient, 0)
                    lam_trajectory.append(lam)
                    if idx_iter >= 10 and np.abs(lam-np.array(lam_trajectory[-1:-6:-1])).max()<1e-5: # the maximal difference, compared to the last 5 iterations, are smaller than 1e-5
                        is_converge = True
                        if verbose:
                            print(f'The optimization converges to a finite maximizer!')
                        break
                if is_converge:
                    if set_optimum:
                        self.lam_star = lam
                    break
                num_loops += 1
                if num_loops >= 5: # fail the optimization after 5 loops
                    print(f'The dual problem (margins={self.margins}, sample_shape={self.helpfulness_scores.shape}) may not have a finite maximizer!')
                    if set_optimum:
                        self.lam_star = None
                    break
            return lam_trajectory if is_converge else None

# %%
log_probs = torch.load('/home/lishuo1/safe-rlhf/output/alpaca-7b-reproduced_log_probs_3epoch_new.pt').cpu().numpy()
full_ref_log_probs_sum = np.sum(log_probs[:, :, 512:1024]*(log_probs[:, :, 512:1024] != 10), axis = -1)
full_helpfulness_log_probs_sum = np.sum(log_probs[:, :, 1536:]*(log_probs[:, :, 1536:] != 10), axis = -1)
full_safety_log_probs_sum = np.sum(log_probs[:, :, 1024:1536]*(log_probs[:, :, 1024:1536] != 10), axis = -1)

# %%
log_probs.shape
# Out:
# (2004, 96, 2048)

# %%
log_probs2 = torch.load('/home/lishuo1/safe-rlhf/output/alpaca-7b-reproduced_log_probs_3epoch_new2.pt').cpu().numpy()
full_ref_log_probs_sum2 = np.sum(log_probs2[:, :, 512:1024]*(log_probs2[:, :, 512:1024] != 10), axis = -1)
full_helpfulness_log_probs_sum2 = np.sum(log_probs2[:, :, 1536:]*(log_probs2[:, :, 1536:] != 10), axis = -1)
full_safety_log_probs_sum2 = np.sum(log_probs2[:, :, 1024:1536]*(log_probs2[:, :, 1024:1536] != 10), axis = -1)

# %%
full_ref_log_probs_sum2.shape
# Out:
# (1604, 96)

# %%
full_ref_log_probs_sum = np.concatenate([full_ref_log_probs_sum[:1604,], full_ref_log_probs_sum2[:1604,]], axis=1)
full_helpfulness_log_probs_sum = np.concatenate([full_helpfulness_log_probs_sum[:1604,], full_helpfulness_log_probs_sum2[:1604,]], axis=1)
full_safety_log_probs_sum = np.concatenate([full_safety_log_probs_sum[:1604,], full_safety_log_probs_sum2[:1604,]], axis=1)

# %% [markdown]
# ## 1. A demo case with constraint $\mathbb{E}_{\pi}[{\rm safety}]-\mathbb{E}_{\pi_{\rm ref}}[{\rm safety}]\geq {\rm margin}=0.5$

# %%
do = DualOptimizer(full_ref_log_probs_sum, full_helpfulness_log_probs_sum, full_safety_log_probs_sum, kl_coeff=0.1, margins=0.5)
lam_trajectory = do.solve(lr=2, max_iters=100, set_optimum=True)

# %%
plt.plot(lam_trajectory)
plt.xlabel('#Iterations', fontsize=15)
plt.ylabel('Optimal Dual', fontsize=15)

plt.grid(True)
plt.grid(which='both', color='gray', linestyle='-', linewidth=0.5)

# %% [markdown]
# ## 2. Dual lanscape with respect to the (margin, #prompts)

# %%
margin_grid = np.linspace(0, 3, 20)
num_prompt_grid = list(np.arange(200, 1604, 200))

lam_mp_list = np.full((len(margin_grid), len(num_prompt_grid)), None, dtype=object)
for idx_mg, margin in enumerate(margin_grid):
    for idx_num, num_prompt in enumerate(num_prompt_grid):
        do = DualOptimizer(full_ref_log_probs_sum[:num_prompt], full_helpfulness_log_probs_sum[:num_prompt], full_safety_log_probs_sum[:num_prompt], kl_coeff=0.1, margins=margin)
        do.solve(lr=2, max_iters=200, set_optimum=True)
        lam_mp_list[idx_mg][idx_num] = do.lam_star
# Out:
# The dual problem (margins=3.0, sample_shape=(600, 192)) may not have a finite maximizer!
# The dual problem (margins=3.0, sample_shape=(1000, 192)) may not have a finite maximizer!
# The dual problem (margins=3.0, sample_shape=(1200, 192)) may not have a finite maximizer!

# %%
fig, axs = plt.subplots(1, 2, figsize=(10, 10))  # Adjust the size as needed
axs = axs.flatten()

cmap = plt.get_cmap('tab20b')
colors = [cmap(i) for i in range(20)]
for idx_mg, margin in enumerate(margin_grid):
    if not np.all(lam_mp_list[idx_mg]==None):
        modified_lam_mp_list = [lam for lam in lam_mp_list[idx_mg]]
        for idx_lam, lam in enumerate(modified_lam_mp_list):
            if lam != None:
                modified_lam_mp_list[idx_lam] = np.maximum(lam, 1e-8)
        axs[0].semilogy(num_prompt_grid, modified_lam_mp_list, label=f'$b$={round(margin, 2)}', color=colors[idx_mg])
        axs[1].plot(num_prompt_grid, modified_lam_mp_list, label=f'$b$={round(margin, 2)}', color=colors[idx_mg])

for i in range(2):
    axs[i].set_xlabel('#Prompts', fontsize=15)
    axs[i].grid(True)
    axs[i].grid(which='both', color='gray', linestyle='-', linewidth=0.5)
axs[0].set_ylabel('Optimal Dual', fontsize=15)
axs[1].legend(loc='upper left', bbox_to_anchor=(1, 1), fontsize=15)


plt.subplots_adjust(top=0.95)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3. Dual lanscape with respect to the (margin, #responses)

# %%
margin_grid = np.linspace(0, 3, 20)
num_response_grid = np.arange(8, 193, 8)

lam_mr_list = np.full((len(margin_grid), len(num_response_grid)), None, dtype=object)
for idx_mg, margin in enumerate(margin_grid):
    for idx_num, num_response in enumerate(num_response_grid):
        do = DualOptimizer(full_ref_log_probs_sum[:,:num_response], full_helpfulness_log_probs_sum[:,:num_response], full_safety_log_probs_sum[:,:num_response], kl_coeff=0.1, margins=margin)
        do.solve(lr=2, max_iters=200, set_optimum=True)
        lam_mr_list[idx_mg][idx_num] = do.lam_star
# Out:
# The dual problem (margins=1.5789473684210527, sample_shape=(1604, 8)) may not have a finite maximizer!
# The dual problem (margins=1.7368421052631577, sample_shape=(1604, 8)) may not have a finite maximizer!
# The dual problem (margins=1.894736842105263, sample_shape=(1604, 8)) may not have a finite maximizer!
# The dual problem (margins=1.894736842105263, sample_shape=(1604, 16)) may not have a finite maximizer!
# The dual problem (margins=2.052631578947368, sample_shape=(1604, 8)) may not have a finite maximizer!
# The dual problem (margins=2.052631578947368, sample_shape=(1604, 16)) may not have a finite maximizer!
# The dual problem (margins=2.052631578947368, sample_shape=(1604, 24)) may not have a finite maximizer!
# The dual problem (margins=2.2105263157894735, sample_shape=(1604, 8)) may not have a finite maximizer!
# The dual problem (margins=2.2105263157894735, sample_shape=(1604, 16)) may not have a finite maximizer!
# The dual problem (margins=2.2105263157894735, sample_shape=(1604, 24)) may not have a finite maximizer!
# The dual problem (margins=2.2105263157894735, sample_shape=(1604, 32)) may not have a finite maximizer!
# The dual problem (margins=2.3684210526315788, sample_shape=(1604, 8)) may not have a finite maximizer!
# The dual problem (margins=2.3684210526315788, sample_shape=(1604, 16)) may not have a finite maximizer!
# The dual problem (margins=2.3684210526315788, sample_shape=(1604, 24)) may not have a finite maximizer!
# The dual problem (margins=2.3684210526315788, sample_shape=(1604, 32)) may not have a finite maximizer!
# The dual problem (margins=2.3684210526315788, sample_shape=(1604, 40)) may not have a finite maximizer!
# The dual problem (margins=2.3684210526315788, sample_shape=(1604, 48)) may not have a finite maximizer!
# The dual problem (margins=2.526315789473684, sample_shape=(1604, 8)) may not have a finite maximizer!
# The dual problem (margins=2.526315789473684, sample_shape=(1604, 16)) may not have a finite maximizer!
# The dual problem (margins=2.526315789473684, sample_shape=(1604, 24)) may not have a finite maximizer!
# The dual problem (margins=2.526315789473684, sample_shape=(1604, 32)) may not have a finite maximizer!
# The dual problem (margins=2.526315789473684, sample_shape=(1604, 40)) may not have a finite maximizer!
# The dual problem (margins=2.526315789473684, sample_shape=(1604, 48)) may not have a finite maximizer!
# The dual problem (margins=2.526315789473684, sample_shape=(1604, 56)) may not have a finite maximizer!
# The dual problem (margins=2.526315789473684, sample_shape=(1604, 64)) may not have a finite maximizer!
# The dual problem (margins=2.6842105263157894, sample_shape=(1604, 8)) may not have a finite maximizer!
# The dual problem (margins=2.6842105263157894, sample_shape=(1604, 16)) may not have a finite maximizer!
# The dual problem (margins=2.6842105263157894, sample_shape=(1604, 24)) may not have a finite maximizer!
# The dual problem (margins=2.6842105263157894, sample_shape=(1604, 32)) may not have a finite maximizer!
# The dual problem (margins=2.6842105263157894, sample_shape=(1604, 40)) may not have a finite maximizer!
# The dual problem (margins=2.6842105263157894, sample_shape=(1604, 48)) may not have a finite maximizer!
# The dual problem (margins=2.6842105263157894, sample_shape=(1604, 56)) may not have a finite maximizer!
# The dual problem (margins=2.6842105263157894, sample_shape=(1604, 64)) may not have a finite maximizer!
# The dual problem (margins=2.6842105263157894, sample_shape=(1604, 72)) may not have a finite maximizer!
# The dual problem (margins=2.6842105263157894, sample_shape=(1604, 80)) may not have a finite maximizer!
# The dual problem (margins=2.6842105263157894, sample_shape=(1604, 88)) may not have a finite maximizer!
# The dual problem (margins=2.8421052631578947, sample_shape=(1604, 8)) may not have a finite maximizer!
# The dual problem (margins=2.8421052631578947, sample_shape=(1604, 16)) may not have a finite maximizer!
# The dual problem (margins=2.8421052631578947, sample_shape=(1604, 24)) may not have a finite maximizer!
# The dual problem (margins=2.8421052631578947, sample_shape=(1604, 32)) may not have a finite maximizer!
# The dual problem (margins=2.8421052631578947, sample_shape=(1604, 40)) may not have a finite maximizer!
# The dual problem (margins=2.8421052631578947, sample_shape=(1604, 48)) may not have a finite maximizer!
# The dual problem (margins=2.8421052631578947, sample_shape=(1604, 56)) may not have a finite maximizer!
# The dual problem (margins=2.8421052631578947, sample_shape=(1604, 64)) may not have a finite maximizer!
# The dual problem (margins=2.8421052631578947, sample_shape=(1604, 72)) may not have a finite maximizer!
# The dual problem (margins=2.8421052631578947, sample_shape=(1604, 80)) may not have a finite maximizer!
# The dual problem (margins=2.8421052631578947, sample_shape=(1604, 88)) may not have a finite maximizer!
# The dual problem (margins=2.8421052631578947, sample_shape=(1604, 96)) may not have a finite maximizer!
# The dual problem (margins=2.8421052631578947, sample_shape=(1604, 104)) may not have a finite maximizer!
# The dual problem (margins=2.8421052631578947, sample_shape=(1604, 112)) may not have a finite maximizer!
# The dual problem (margins=2.8421052631578947, sample_shape=(1604, 120)) may not have a finite maximizer!
# The dual problem (margins=2.8421052631578947, sample_shape=(1604, 128)) may not have a finite maximizer!
# The dual problem (margins=3.0, sample_shape=(1604, 8)) may not have a finite maximizer!
# The dual problem (margins=3.0, sample_shape=(1604, 16)) may not have a finite maximizer!
# The dual problem (margins=3.0, sample_shape=(1604, 24)) may not have a finite maximizer!
# The dual problem (margins=3.0, sample_shape=(1604, 32)) may not have a finite maximizer!
# The dual problem (margins=3.0, sample_shape=(1604, 40)) may not have a finite maximizer!
# The dual problem (margins=3.0, sample_shape=(1604, 48)) may not have a finite maximizer!
# The dual problem (margins=3.0, sample_shape=(1604, 56)) may not have a finite maximizer!
# The dual problem (margins=3.0, sample_shape=(1604, 64)) may not have a finite maximizer!
# The dual problem (margins=3.0, sample_shape=(1604, 72)) may not have a finite maximizer!
# The dual problem (margins=3.0, sample_shape=(1604, 80)) may not have a finite maximizer!
# The dual problem (margins=3.0, sample_shape=(1604, 88)) may not have a finite maximizer!
# The dual problem (margins=3.0, sample_shape=(1604, 96)) may not have a finite maximizer!
# The dual problem (margins=3.0, sample_shape=(1604, 104)) may not have a finite maximizer!
# The dual problem (margins=3.0, sample_shape=(1604, 112)) may not have a finite maximizer!
# The dual problem (margins=3.0, sample_shape=(1604, 120)) may not have a finite maximizer!
# The dual problem (margins=3.0, sample_shape=(1604, 128)) may not have a finite maximizer!
# The dual problem (margins=3.0, sample_shape=(1604, 136)) may not have a finite maximizer!
# The dual problem (margins=3.0, sample_shape=(1604, 144)) may not have a finite maximizer!
# The dual problem (margins=3.0, sample_shape=(1604, 152)) may not have a finite maximizer!
# The dual problem (margins=3.0, sample_shape=(1604, 160)) may not have a finite maximizer!
# The dual problem (margins=3.0, sample_shape=(1604, 168)) may not have a finite maximizer!
# The dual problem (margins=3.0, sample_shape=(1604, 176)) may not have a finite maximizer!

# %%
fig, axs = plt.subplots(1, 2, figsize=(10, 10))  # Adjust the size as needed
axs = axs.flatten()

cmap = plt.get_cmap('tab20b')
colors = [cmap(i) for i in range(20)]
for idx_mg, margin in enumerate(margin_grid):
    if not np.all(lam_mp_list[idx_mg]==None):
        modified_lam_mr_list = [lam for lam in lam_mr_list[idx_mg]]
        for idx_lam, lam in enumerate(modified_lam_mr_list):
            if lam != None:
                modified_lam_mr_list[idx_lam] = np.maximum(lam, 1e-8)
        axs[0].semilogy(num_response_grid, modified_lam_mr_list, label=f'$b$={round(margin, 2)}', color=colors[idx_mg])
        axs[1].plot(num_response_grid, modified_lam_mr_list, label=f'$b$={round(margin, 2)}', color=colors[idx_mg])

for i in range(2):
    axs[i].set_xlabel('#Responses', fontsize=15)
    axs[i].grid(True)
    axs[i].grid(which='both', color='gray', linestyle='-', linewidth=0.5)
axs[0].set_ylabel('Optimal Dual', fontsize=15)
axs[1].legend(loc='upper left', bbox_to_anchor=(1, 1), fontsize=15)


plt.subplots_adjust(top=0.95)
plt.tight_layout()
plt.show()

# %%
np.linspace(0.1, 1.5, 4)
# Out:
# array([0.1       , 0.56666667, 1.03333333, 1.5       ])
